# %% [markdown]
# <a href="https://colab.research.google.com/github/blablabla115/hello-world/blob/master/bubbleSortVSbubbleSort2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Complejidad**
#
# $$
# \Theta (n) = n^2
# $$

# %% [markdown]
# # Ejercicios

# %% [markdown]
# *   Realizar el estudio a la siguiente variación del algoritmo:
# ```
# def bubbleSort2(A):
#         bandera = True
#         pasada = 0
#         while pasada < len(A) and bandera:
#             bandera = False
#             for j in range(len(A) - 1):
#                 if A[j] > A[j+1]:
#                     bandera = True
#                     temp = A[j]
#                     A[j] = A[j+1]
#                     A[j+1] = temp
#             pasada += 1
# ```
#
#
# *   Comparar con la primera versión
#
# *   Realizar el estudio para el mejor, promedio y peor escenario para la primera y segunda version bubbleSort

# %%
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort2(A):
    bandera = True
    pasada = 0
    while pasada < len(A) and bandera:
        bandera = False
        for j in range(len(A) - 1):
            if A[j] > A[j+1]:
                bandera = True
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp
        pasada += 1

def bubbleSort(A):
    for i in range (1,len(A)):
        for j in range(len(A) -1):
            if A[j] > A[j+1]:
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp

def generar_arreglo(N):
    A = []
    for i in range (N):
        A.append(random.randrange(100))
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

def calcular_tiempo_bubble2(A):
    tiempo_inicial = time()
    bubbleSort2(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n1 = []
T_n = []
n1 = []
N = 1001
for i in range(0,N,100):
    Arreglo1 = generar_arreglo(i)
    Arreglo2 = generar_arreglo(i)
    n1.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo1))
    T_n1.append(calcular_tiempo_bubble2(Arreglo2))
print(T_n)
#comparación de los dos algoritmos
plt.plot(n1,T_n)
plt.plot(n1,T_n1)
plt.grid()
plt.title('T(n) Bubble Sort(Azul) vs Bubble Sort 2(Naranja)')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()
# Out:
# [1.6689300537109375e-06, 0.001092672348022461, 0.004663228988647461, 0.009773015975952148, 0.017325401306152344, 0.03281688690185547, 0.041251182556152344, 0.05681419372558594, 0.0762937068939209, 0.09534955024719238, 0.12091660499572754]

# %% [markdown]
# **MEJOR, PROMEDIO, PEOR CASO EN EL ALGORITMO BUBBLESORT**

# %%
#bubbleSort en el mejor caso
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort(A):
    for i in range (1,len(A)):
        for j in range(len(A) -1):
            if A[j] > A[j+1]:
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp

#generamos un arreglo ordenado
def generar_arreglo(N):
    A = []
    for i in range (N):
        A.append(i)
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %%
#bubbleSort en el caso promedio
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort(A):
    for i in range (1,len(A)):
        for j in range(len(A) -1):
            if A[j] > A[j+1]:
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp

#generamos un arreglo con elementos desordenados
def generar_arreglo(N):
    A = []
    for i in range (N):
        A.append(random.randrange(100))
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %%
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort(A):
    for i in range (1,len(A)):
        for j in range(len(A) -1):
            if A[j] > A[j+1]:
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp

#generamos un arreglo cuyos elementos esten ordenados de forma decreciente
def generar_arreglo(N):
    A = []
    elemento = N;
    for i in range (N):
        A.append(elemento-1)
        elemento -= 1
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %% [markdown]
# **MEJOR, PROMEDIO, PEOR CASO EN EL ALGORITMO BUBBLESORT 2**

# %%
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort2(A):
    bandera = True
    pasada = 0
    while pasada < len(A) and bandera:
        bandera = False
        for j in range(len(A) - 1):
            if A[j] > A[j+1]:
                bandera = True
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp
        pasada += 1

#Generamos un arreglo ordenado        
def generar_arreglo(N):
    A = []
    for i in range (N):
        A.append(i)
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort 2')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %%
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort2(A):
    bandera = True
    pasada = 0
    while pasada < len(A) and bandera:
        bandera = False
        for j in range(len(A) - 1):
            if A[j] > A[j+1]:
                bandera = True
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp
        pasada += 1

#generamos un arreglo con elementos desordenados
def generar_arreglo(N):
    A = []
    for i in range (N):
        A.append(random.randrange(100))
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort 2')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %%
import random
import matplotlib.pyplot  as plt
from time import time

def bubbleSort2(A):
    bandera = True
    pasada = 0
    while pasada < len(A) and bandera:
        bandera = False
        for j in range(len(A) - 1):
            if A[j] > A[j+1]:
                bandera = True
                temp = A[j]
                A[j] = A[j+1]
                A[j+1] = temp
        pasada += 1

#generamos un arreglo con elementos ordenados en forma decreciente
def generar_arreglo(N):
    A = []
    elemento = N
    for i in range (N):
        A.append(elemento-1)
        elemento -= 1
    return A

def calcular_tiempo_bubble(A):
    tiempo_inicial = time()
    bubbleSort(A)
    tiempo_final = time()
    return tiempo_final - tiempo_inicial

# Main
T_n = []
n = []
N = 1001
for i in range(0,N,100):
    Arreglo = generar_arreglo(i)
    n.append(i)
    T_n.append(calcular_tiempo_bubble(Arreglo))

# Gráfica
plt.plot(n,T_n)
plt.grid()
plt.title('T(n) Bubble Sort 2')
plt.xlabel('n')
plt.ylabel('T(n)')
plt.show()

# %% [markdown]
# **Concluciones**
#
# Las gráficas muestran que el algoritmo bubbleSort es mas veloz que el algoritmo bubbleSort 2 en el peor caso
